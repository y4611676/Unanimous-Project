# %% [markdown]
# # Import needed module 導入需要的模組

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Data prepare 資料準備

# %% [markdown]
# import needed dataset導入需要的資料集

# %%
jan_2023 = pd.read_csv("MACOSX/202301-divvy-tripdata.csv")
feb_2023 = pd.read_csv("MACOSX/202302-divvy-tripdata.csv")
mar_2023 = pd.read_csv("MACOSX/202303-divvy-tripdata.csv")
apr_2023 = pd.read_csv("MACOSX/202304-divvy-tripdata.csv")
may_2023 = pd.read_csv("MACOSX/202305-divvy-tripdata.csv")
jun_2023 = pd.read_csv("MACOSX/202306-divvy-tripdata.csv")
jul_2023 = pd.read_csv("MACOSX/202307-divvy-tripdata.csv")
aug_2023 = pd.read_csv("MACOSX/202308-divvy-tripdata.csv")
sep_2023 = pd.read_csv("MACOSX/202309-divvy-tripdata.csv")
oct_2023 = pd.read_csv("MACOSX/202310-divvy-tripdata.csv")
nov_2023 = pd.read_csv("MACOSX/202311-divvy-tripdata.csv")
dec_2023 = pd.read_csv("MACOSX/202312-divvy-tripdata.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 jan_2023 = pd.read_csv("MACOSX/202301-divvy-tripdata.csv")
#       2 feb_2023 = pd.read_csv("MACOSX/202302-divvy-tripdata.csv")
#       3 mar_2023 = pd.read_csv("MACOSX/202303-divvy-tripdata.csv")
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'MACOSX/202301-divvy-tripdata.csv'

# %% [markdown]
# set up combine dataset設定組合資料集

# %%
data = pd.concat([jan_2023,feb_2023,mar_2023,apr_2023,may_2023,
                  jun_2023,jul_2023,aug_2023,sep_2023,oct_2023,nov_2023,dec_2023],
                 ignore_index = True)
data.info()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5719877 entries, 0 to 5719876
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 567.3+ MB
#                   ride_id  rideable_type           started_at  \
# 0        F96D5A74A3E41399  electric_bike  2023-01-21 20:05:42
# 1        13CB7EB698CEDB88   classic_bike  2023-01-10 15:37:36
# 2        BD88A2E670661CE5  electric_bike  2023-01-02 07:51:57
# 3        C90792D034FED968   classic_bike  2023-01-22 10:52:58
# 4        3397017529188E8A   classic_bike  2023-01-12 13:58:01
# ...                   ...            ...                  ...
# 5719872  F74DF9549B504A6B  electric_bike  2023-12-07 13:15:24
# 5719873  BCDA66E761CC1029   classic_bike  2023-12-08 18:42:21
# 5719874  D2CF330F9C266683   classic_bike  2023-12-05 14:09:11
# 5719875  3829A0D1E00EE970  electric_bike  2023-12-02 21:36:07
# 5719876  A373F5B447AEA508   classic_bike  2023-12-11 13:07:46
#
#                     ended_at           start_station_name start_station_id  \
# 0        2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2        2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3        2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4        2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                      ...                          ...              ...
# 5719872  2023-12-07 13:17:37            900 W Harrison St            13028
# 5719873  2023-12-08 18:45:56            900 W Harrison St            13028
# 5719874  2023-12-05 14:13:01            900 W Harrison St            13028
# 5719875  2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 5719876  2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 5719872      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 5719873      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 5719874      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 5719875            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 5719876      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng member_casual
# 0        41.930000 -87.640000        member
# 1        41.809835 -87.599383        member
# 2        42.039742 -87.699413        casual
# 3        41.809835 -87.599383        member
# 4        41.809835 -87.599383        member
# ...            ...        ...           ...
# 5719872  41.874640 -87.657030        casual
# 5719873  41.874640 -87.657030        casual
# 5719874  41.874640 -87.657030        member
# 5719875  41.885492 -87.652289        casual
# 5719876  41.874640 -87.657030        member
#
# [5719877 rows x 13 columns]

# %% [markdown]
# Data Cleaning and Manipulating Process 資料清理和操作過程

# %%
# Checking the null values and counting with the sum() function
# 檢查空值並使用 sum() 函數進行計數
data.isna().sum()
# Out:
# ride_id                    0
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    875716
# start_station_id      875848
# end_station_name      929202
# end_station_id        929343
# start_lat                  0
# start_lng                  0
# end_lat                 6990
# end_lng                 6990
# member_casual              0
# dtype: int64

# %% [markdown]
# Dropping null values刪除空值

# %%
data.dropna(inplace= True)
data.isna().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# dtype: int64

# %% [markdown]
# Converting datatype of "started_at" & "ended_at" columns to "datetime64" type.
# 將“started_at”和“ending_at”列的資料類型轉換為“datetime64”類型。

# %%
data['started_at'] = pd.to_datetime(data['started_at'])
data['ended_at'] = pd.to_datetime(data['ended_at'])

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4331707 entries, 0 to 5719876
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 462.7+ MB

# %% [markdown]
# Creating New Column "ride_length" and changing its datatype to "int32"
# 建立新列“ride_length”並將其資料類型變更為“int32”

# %%
# In this column, each row contains the difference between "started_at and "ended_at" columns in minutes.
data['ride_length'] = (data['ended_at'] - data['started_at'])/pd.Timedelta(minutes=1)
data['ride_length'] = data['ride_length'].astype('int32')

data.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42 2023-01-21 20:16:33
# 1  13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36 2023-01-10 15:46:05
# 2  BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57 2023-01-02 08:05:11
# 3  C90792D034FED968   classic_bike 2023-01-22 10:52:58 2023-01-22 11:01:44
# 4  3397017529188E8A   classic_bike 2023-01-12 13:58:01 2023-01-12 14:13:20
#
#             start_station_name start_station_id  \
# 0  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        Kimbark Ave & 53rd St     TA1309000037
# 2       Western Ave & Lunt Ave           RP-005
# 3        Kimbark Ave & 53rd St     TA1309000037
# 4        Kimbark Ave & 53rd St     TA1309000037
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0       Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2  Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
#
#      end_lat    end_lng member_casual  ride_length
# 0  41.930000 -87.640000        member           10
# 1  41.809835 -87.599383        member            8
# 2  42.039742 -87.699413        casual           13
# 3  41.809835 -87.599383        member            8
# 4  41.809835 -87.599383        member           15

# %% [markdown]
# Sorting Values by "ride_length" column in Ascending orde
# 按“ride_length”欄位以升序對數值進行排序

# %%
data.sort_values(by = 'ride_length')
# Out:
#                   ride_id rideable_type          started_at  \
# 5452383  5C5FCC49C148635F  classic_bike 2023-11-05 01:55:47
# 5415699  D17C0701A2AC27A8  classic_bike 2023-11-05 01:53:49
# 5433976  274EDE47C11F43AF  classic_bike 2023-11-05 01:55:51
# 5257025  0AF3917F317F4C5F  classic_bike 2023-11-05 01:54:43
# 5212240  FBDEF92A65F125D9  classic_bike 2023-11-05 01:58:37
# ...                   ...           ...                 ...
# 2102616  3BC5FFFDF7503DAA   docked_bike 2023-06-15 13:28:59
# 3229464  4031082BC503CC84   docked_bike 2023-08-02 17:28:57
# 3432392  47158A16C754A9F4   docked_bike 2023-08-10 22:17:49
# 2104833  FA287922CA358CE0   docked_bike 2023-06-03 17:52:15
# 1078713  59AD7EE868FC6588   docked_bike 2023-05-30 12:48:08
#
#                    ended_at                 start_station_name  \
# 5452383 2023-11-05 01:01:13        Halsted St & Wrightwood Ave
# 5415699 2023-11-05 01:00:41        Halsted St & Wrightwood Ave
# 5433976 2023-11-05 01:02:37     Southport Ave & Wellington Ave
# 5257025 2023-11-05 01:01:31               Halsted St & 21st St
# 5212240 2023-11-05 01:05:42              LaSalle Dr & Huron St
# ...                     ...                                ...
# 2102616 2023-06-18 23:12:06  DuSable Lake Shore Dr & Monroe St
# 3229464 2023-08-06 11:07:57           University Ave & 57th St
# 3432392 2023-08-15 17:09:02          Larrabee St & Webster Ave
# 2104833 2023-06-11 11:44:31         Fort Dearborn Dr & 31st St
# 1078713 2023-06-07 23:04:26                 Wells St & Polk St
#
#         start_station_id                end_station_name end_station_id  \
# 5452383     TA1309000061          Halsted St & Roscoe St   TA1309000025
# 5415699     TA1309000061       Sedgwick St & Webster Ave          13191
# 5433976     TA1307000006  Southport Ave & Wrightwood Ave   TA1307000113
# 5257025            13162            Racine Ave & 18th St          13164
# 5212240     KP1705001026               Clark St & Elm St   TA1307000039
# ...                  ...                             ...            ...
# 2102616            13300     Fort Dearborn Dr & 31st St*  chargingstx06
# 3229464     KA1503000071  Museum of Science and Industry   KA1503000074
# 3432392            13193           Michigan Ave & Oak St          13042
# 2104833     TA1307000048     Fort Dearborn Dr & 31st St*  chargingstx06
# 1078713           SL-011        Lincoln Ave & Roscoe St*   chargingstx5
#
#          start_lat  start_lng    end_lat    end_lng member_casual  ride_length
# 5452383  41.929143 -87.649077  41.943670 -87.648950        member          -54
# 5415699  41.929143 -87.649077  41.922167 -87.638888        member          -53
# 5433976  41.935775 -87.663600  41.928773 -87.663913        casual          -53
# 5257025  41.853780 -87.646603  41.858166 -87.656495        casual          -53
# 5212240  41.894877 -87.632326  41.902973 -87.631280        casual          -52
# ...            ...        ...        ...        ...           ...          ...
# 2102616  41.880958 -87.616743  41.838676 -87.608832        casual         4903
# 3229464  41.791478 -87.599861  41.791728 -87.583945        casual         5379
# 3432392  41.921822 -87.644140  41.900960 -87.623777        casual         6891
# 2104833  41.838556 -87.608218  41.838676 -87.608832        casual        11152
# 1078713  41.872732 -87.633516  41.943350 -87.670668        casual        12136
#
# [4331707 rows x 14 columns]

# %% [markdown]
# Removing rows containing negative values
# 刪除包含負值的行

# %%
data = data[data['ride_length'] > 0]
data = data.reset_index()
data = data.drop(columns=['index'])
 
data
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42
# 1        13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36
# 2        BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57
# 3        C90792D034FED968   classic_bike 2023-01-22 10:52:58
# 4        3397017529188E8A   classic_bike 2023-01-12 13:58:01
# ...                   ...            ...                 ...
# 4244184  F74DF9549B504A6B  electric_bike 2023-12-07 13:15:24
# 4244185  BCDA66E761CC1029   classic_bike 2023-12-08 18:42:21
# 4244186  D2CF330F9C266683   classic_bike 2023-12-05 14:09:11
# 4244187  3829A0D1E00EE970  electric_bike 2023-12-02 21:36:07
# 4244188  A373F5B447AEA508   classic_bike 2023-12-11 13:07:46
#
#                    ended_at           start_station_name start_station_id  \
# 0       2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1       2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2       2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3       2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4       2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                     ...                          ...              ...
# 4244184 2023-12-07 13:17:37            900 W Harrison St            13028
# 4244185 2023-12-08 18:45:56            900 W Harrison St            13028
# 4244186 2023-12-05 14:13:01            900 W Harrison St            13028
# 4244187 2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 4244188 2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 4244184      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 4244185      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4244186      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4244187            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 4244188      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng member_casual  ride_length
# 0        41.930000 -87.640000        member           10
# 1        41.809835 -87.599383        member            8
# 2        42.039742 -87.699413        casual           13
# 3        41.809835 -87.599383        member            8
# 4        41.809835 -87.599383        member           15
# ...            ...        ...           ...          ...
# 4244184  41.874640 -87.657030        casual            2
# 4244185  41.874640 -87.657030        casual            3
# 4244186  41.874640 -87.657030        member            3
# 4244187  41.885492 -87.652289        casual           17
# 4244188  41.874640 -87.657030        member            3
#
# [4244189 rows x 14 columns]

# %% [markdown]
# Using the dt.day_name() to get the name of the day to each date
# 使用 dt.day_name() 取得每個日期的日期名稱

# %%
data["started_at"].dt.day_name()
# Out:
# 0          Saturday
# 1           Tuesday
# 2            Monday
# 3            Sunday
# 4          Thursday
#              ...
# 4244184    Thursday
# 4244185      Friday
# 4244186     Tuesday
# 4244187    Saturday
# 4244188      Monday
# Name: started_at, Length: 4244189, dtype: object

# %%
# df['month_of_date'] = df['date_given'].dt.month
data["started_at"].dt.month
# Out:
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#            ..
# 4244184    12
# 4244185    12
# 4244186    12
# 4244187    12
# 4244188    12
# Name: started_at, Length: 4244189, dtype: int32

# %% [markdown]
# Using the dt.month_name to see the months of each date
# 使用 dt.month_name 查看每個日期的月份

# %%
# later assign it into a new column
data["started_at"].dt.month_name()
# Out:
# 0           January
# 1           January
# 2           January
# 3           January
# 4           January
#              ...
# 4244184    December
# 4244185    December
# 4244186    December
# 4244187    December
# 4244188    December
# Name: started_at, Length: 4244189, dtype: object

# %% [markdown]
# Extracting the specific day提取特定日期

# %%
data["started_at"].dt.day
# Out:
# 0          21
# 1          10
# 2           2
# 3          22
# 4          12
#            ..
# 4244184     7
# 4244185     8
# 4244186     5
# 4244187     2
# 4244188    11
# Name: started_at, Length: 4244189, dtype: int32

# %% [markdown]
# Now taking the year this "dt." is kind a library to manipulate date
# 現在以年份為「dt」。是一個操縱日期的庫

# %%
data["started_at"].dt.year
# Out:
# 0          2023
# 1          2023
# 2          2023
# 3          2023
# 4          2023
#            ...
# 4244184    2023
# 4244185    2023
# 4244186    2023
# 4244187    2023
# 4244188    2023
# Name: started_at, Length: 4244189, dtype: int32

# %% [markdown]
# Create and insert new columns
# 建立並插入新列

# %%
data["weekday"] = data["started_at"].dt.day_name()
data["day"] = data["started_at"].dt.day
data["month"] = data["started_at"].dt.month
data["month_name"] = data["started_at"].dt.month_name()
data["year"] = data["started_at"].dt.year

data
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42
# 1        13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36
# 2        BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57
# 3        C90792D034FED968   classic_bike 2023-01-22 10:52:58
# 4        3397017529188E8A   classic_bike 2023-01-12 13:58:01
# ...                   ...            ...                 ...
# 4244184  F74DF9549B504A6B  electric_bike 2023-12-07 13:15:24
# 4244185  BCDA66E761CC1029   classic_bike 2023-12-08 18:42:21
# 4244186  D2CF330F9C266683   classic_bike 2023-12-05 14:09:11
# 4244187  3829A0D1E00EE970  electric_bike 2023-12-02 21:36:07
# 4244188  A373F5B447AEA508   classic_bike 2023-12-11 13:07:46
#
#                    ended_at           start_station_name start_station_id  \
# 0       2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1       2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2       2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3       2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4       2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                     ...                          ...              ...
# 4244184 2023-12-07 13:17:37            900 W Harrison St            13028
# 4244185 2023-12-08 18:45:56            900 W Harrison St            13028
# 4244186 2023-12-05 14:13:01            900 W Harrison St            13028
# 4244187 2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 4244188 2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 4244184      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 4244185      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4244186      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4244187            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 4244188      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng member_casual  ride_length   weekday  day  \
# 0        41.930000 -87.640000        member           10  Saturday   21
# 1        41.809835 -87.599383        member            8   Tuesday   10
# 2        42.039742 -87.699413        casual           13    Monday    2
# 3        41.809835 -87.599383        member            8    Sunday   22
# 4        41.809835 -87.599383        member           15  Thursday   12
# ...            ...        ...           ...          ...       ...  ...
# 4244184  41.874640 -87.657030        casual            2  Thursday    7
# 4244185  41.874640 -87.657030        casual            3    Friday    8
# 4244186  41.874640 -87.657030        member            3   Tuesday    5
# 4244187  41.885492 -87.652289        casual           17  Saturday    2
# 4244188  41.874640 -87.657030        member            3    Monday   11
#
#          month month_name  year
# 0            1    January  2023
# 1            1    January  2023
# 2            1    January  2023
# 3            1    January  2023
# 4            1    January  2023
# ...        ...        ...   ...
# 4244184     12   December  2023
# 4244185     12   December  2023
# 4244186     12   December  2023
# 4244187     12   December  2023
# 4244188     12   December  2023
#
# [4244189 rows x 19 columns]

# %% [markdown]
# Checking the number of unique values for each column.
# 檢查每列的唯一值的數量。

# %%
data.nunique()
# Out:
# ride_id               4244189
# rideable_type               3
# started_at            3722350
# ended_at              3733231
# start_station_name       1518
# start_station_id         1453
# end_station_name         1548
# end_station_id           1476
# start_lat              679019
# start_lng              644661
# end_lat                  9341
# end_lng                  9408
# member_casual               2
# ride_length              1467
# weekday                     7
# day                        31
# month                      12
# month_name                 12
# year                        1
# dtype: int64

# %% [markdown]
# Using the duplicated() function combined with the sum() to have the total number of duplicated values
# 使用duplicate()函數結合sum()得到重複值的總數

# %%
data["ride_id"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# export cleaned dataset
# 匯出清理後的資料集

# %%
data_cleaned = data

# %%
# df.to_csv("your_name.csv")
data_cleaned.to_csv("data_clean.csv")

# %% [markdown]
# # Data analysis english數據分析英文

# %%
data_cleaned = pd.read_csv("data_clean.csv")
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4244189 entries, 0 to 4244188
# Data columns (total 20 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   ride_id             object
#  2   rideable_type       object
#  3   started_at          object
#  4   ended_at            object
#  5   start_station_name  object
#  6   start_station_id    object
#  7   end_station_name    object
#  8   end_station_id      object
#  9   start_lat           float64
#  10  start_lng           float64
#  11  end_lat             float64
#  12  end_lng             float64
#  13  member_casual       object
#  14  ride_length         int64
#  15  weekday             object
#  16  day                 int64
#  17  month               int64
#  18  month_name          object
#  19  year                int64
# dtypes: float64(4), int64(5), object(11)
# memory usage: 647.6+ MB

# %% [markdown]
# Percentage of total users
# 佔總用戶的百分比

# %%
percent = round(data_cleaned["member_casual"].value_counts(normalize = True) * 100, 1)
percent
# Out:
# member_casual
# member    64.5
# casual    35.5
# Name: proportion, dtype: float64

# %% [markdown]
# See the average ride length by each day for members vs casual user
# 查看會員與休閒用戶每天的平均騎乘長度

# %%
data_cleaned.groupby(['member_casual','weekday']).ride_length.mean()
# Out:
# member_casual  weekday
# casual         Friday       22.199486
#                Monday       22.434500
#                Saturday     25.879738
#                Sunday       26.547451
#                Thursday     19.842879
#                Tuesday      20.371842
#                Wednesday    19.441420
# member         Friday       11.810818
#                Monday       11.303922
#                Saturday     13.408318
#                Sunday       13.422293
#                Thursday     11.364379
#                Tuesday      11.398053
#                Wednesday    11.332991
# Name: ride_length, dtype: float64

# %% [markdown]
# fix the days of the week that are out of order
# 修復一週中不按順序排列的日子。

# %%
day_order = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']
data_cleaned['weekday'] = pd.Categorical(data_cleaned['weekday'], categories=day_order, ordered=True)
data_cleaned
# Out:
#          Unnamed: 0           ride_id  rideable_type           started_at  \
# 0                 0  F96D5A74A3E41399  electric_bike  2023-01-21 20:05:42
# 1                 1  13CB7EB698CEDB88   classic_bike  2023-01-10 15:37:36
# 2                 2  BD88A2E670661CE5  electric_bike  2023-01-02 07:51:57
# 3                 3  C90792D034FED968   classic_bike  2023-01-22 10:52:58
# 4                 4  3397017529188E8A   classic_bike  2023-01-12 13:58:01
# ...             ...               ...            ...                  ...
# 4244184     4244184  F74DF9549B504A6B  electric_bike  2023-12-07 13:15:24
# 4244185     4244185  BCDA66E761CC1029   classic_bike  2023-12-08 18:42:21
# 4244186     4244186  D2CF330F9C266683   classic_bike  2023-12-05 14:09:11
# 4244187     4244187  3829A0D1E00EE970  electric_bike  2023-12-02 21:36:07
# 4244188     4244188  A373F5B447AEA508   classic_bike  2023-12-11 13:07:46
#
#                     ended_at           start_station_name start_station_id  \
# 0        2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2        2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3        2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4        2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                      ...                          ...              ...
# 4244184  2023-12-07 13:17:37            900 W Harrison St            13028
# 4244185  2023-12-08 18:45:56            900 W Harrison St            13028
# 4244186  2023-12-05 14:13:01            900 W Harrison St            13028
# 4244187  2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 4244188  2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 4244184      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 4244185      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4244186      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4244187            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 4244188      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng member_casual  ride_length   weekday  day  \
# 0        41.930000 -87.640000        member           10  Saturday   21
# 1        41.809835 -87.599383        member            8   Tuesday   10
# 2        42.039742 -87.699413        casual           13    Monday    2
# 3        41.809835 -87.599383        member            8    Sunday   22
# 4        41.809835 -87.599383        member           15  Thursday   12
# ...            ...        ...           ...          ...       ...  ...
# 4244184  41.874640 -87.657030        casual            2  Thursday    7
# 4244185  41.874640 -87.657030        casual            3    Friday    8
# 4244186  41.874640 -87.657030        member            3   Tuesday    5
# 4244187  41.885492 -87.652289        casual           17  Saturday    2
# 4244188  41.874640 -87.657030        member            3    Monday   11
#
#          month month_name  year
# 0            1    January  2023
# 1            1    January  2023
# 2            1    January  2023
# 3            1    January  2023
# 4            1    January  2023
# ...        ...        ...   ...
# 4244184     12   December  2023
# 4244185     12   December  2023
# 4244186     12   December  2023
# 4244187     12   December  2023
# 4244188     12   December  2023
#
# [4244189 rows x 20 columns]

# %% [markdown]
# The average ride time by each day for members vs casual user
# 會員與休閒用戶每天的平均騎乘時間

# %%
data_cleaned.groupby(['member_casual','weekday']).ride_length.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11208\2585966250.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data_cleaned.groupby(['member_casual','weekday']).ride_length.mean()
# member_casual  weekday
# casual         Sunday       26.547451
#                Monday       22.434500
#                Tuesday      20.371842
#                Wednesday    19.441420
#                Thursday     19.842879
#                Friday       22.199486
#                Saturday     25.879738
# member         Sunday       13.422293
#                Monday       11.303922
#                Tuesday      11.398053
#                Wednesday    11.332991
#                Thursday     11.364379
#                Friday       11.810818
#                Saturday     13.408318
# Name: ride_length, dtype: float64

# %% [markdown]
# Analyse how casual and member use differently
# 分析休閒和會員的使用方式有何不同

# %%
data_cleaned_1 = data_cleaned.groupby('member_casual', as_index = False)['ride_length'].agg('mean')
data_cleaned_1
# Out:
#   member_casual  ride_length
# 0        casual    22.841623
# 1        member    11.901910

# %% [markdown]
# Run the average ride time by each day for members vs casual users and analyze ridership data by type and weekday
# 計算會員與臨時用戶每天的平均乘車時間，並按類型和工作日分析客流量數據

# %%
data_cleaned_2 = data_cleaned.groupby(['member_casual', 'weekday'], as_index=False, observed=False)['ride_length'].agg('mean')
data_cleaned_2
# Out:
#    member_casual    weekday  ride_length
# 0         casual     Sunday    26.547451
# 1         casual     Monday    22.434500
# 2         casual    Tuesday    20.371842
# 3         casual  Wednesday    19.441420
# 4         casual   Thursday    19.842879
# 5         casual     Friday    22.199486
# 6         casual   Saturday    25.879738
# 7         member     Sunday    13.422293
# 8         member     Monday    11.303922
# 9         member    Tuesday    11.398053
# 10        member  Wednesday    11.332991
# 11        member   Thursday    11.364379
# 12        member     Friday    11.810818
# 13        member   Saturday    13.408318

# %% [markdown]
# Above group by columns member_casual and weekday becomes Index of the DataFrame, In order to get these as a SQL like group by use as_index =False param or use reset_index().
#
# See the average ride time by each month for members vs casual user
#
# 上面的 group by 欄位 member_casual 和 weekday 成為 DataFrame 的索引，為了透過使用 as_index =False 參數或使用 reset_index() 將它們作為類似 SQL 的群組。
#
# 查看會員與休閒用戶每月的平均乘車時間

# %%
data_cleaned_3=data_cleaned.groupby(['member_casual','month', 'month_name'], as_index=False)['ride_length'].agg('mean')
data_cleaned_3
# Out:
#    member_casual  month month_name  ride_length
# 0         casual      1    January    14.684229
# 1         casual      2   February    17.520689
# 2         casual      3      March    16.603642
# 3         casual      4      April    22.619075
# 4         casual      5        May    24.500550
# 5         casual      6       June    24.005900
# 6         casual      7       July    25.176447
# 7         casual      8     August    24.245721
# 8         casual      9  September    23.396853
# 9         casual     10    October    21.213741
# 10        casual     11   November    17.642042
# 11        casual     12   December    16.277168
# 12        member      1    January     9.782528
# 13        member      2   February    10.202424
# 14        member      3      March    10.000773
# 15        member      4      April    11.437898
# 16        member      5        May    12.507738
# 17        member      6       June    12.704286
# 18        member      7       July    13.128345
# 19        member      8     August    13.072830
# 20        member      9  September    12.403233
# 21        member     10    October    11.360476
# 22        member     11   November    10.752742
# 23        member     12   December    10.522303

# %% [markdown]
# Count the rides, given both user, and bike type
# 根據使用者和自行車類型計算騎乘次數

# %%
data_cleaned_4 = data_cleaned.groupby(['member_casual','rideable_type'])['ride_id'].count().rename_axis(['member_casual', 'rideable_type']).reset_index(name = 'count')
data_cleaned_4
# Out:
#   member_casual  rideable_type    count
# 0        casual   classic_bike   860702
# 1        casual    docked_bike    75412
# 2        casual  electric_bike   569179
# 3        member   classic_bike  1788780
# 4        member  electric_bike   950116

# %% [markdown]
# no of ride by each month for members vs casual user
# 會員與休閒用戶每月的乘車次數

# %%
data_cleaned_5=data_cleaned.groupby(['member_casual','month', 'month_name'], as_index=False)['ride_id'].agg('count')
data_cleaned_5
# Out:
#    member_casual  month month_name  ride_id
# 0         casual      1    January    29021
# 1         casual      2   February    32142
# 2         casual      3      March    45739
# 3         casual      4      April   108163
# 4         casual      5        May   173677
# 5         casual      6       June   215931
# 6         casual      7       July   240900
# 7         casual      8     August   230188
# 8         casual      9  September   193991
# 9         casual     10    October   128319
# 10        casual     11   November    71067
# 11        casual     12   December    36155
# 12        member      1    January   115445
# 13        member      2   February   113712
# 14        member      3      March   148811
# 15        member      4      April   206758
# 16        member      5        May   279260
# 17        member      6       June   308795
# 18        member      7       July   321969
# 19        member      8     August   344307
# 20        member      9  September   304189
# 21        member     10    October   268642
# 22        member     11   November   199132
# 23        member     12   December   127876

# %% [markdown]
# # Data visualization 數據視覺化

# %% [markdown]
# Visualize Percentage of Total Users
# 總用戶的百分比可視化

# %%
member_casual = ['member', 'casual']
fig = plt.figure(figsize =(10, 7))
plt.pie(percent, labels = member_casual, autopct = "%0.1f%%")
plt.title("Percentage of Total Users")
plt.savefig('Percentage of Total Users', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Average Ride Length Member vs Casual in 2023
# 2023 年會員與休閒的平均騎乘長度

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(data_cleaned_1['ride_length'], labels = data_cleaned_1['member_casual'], autopct = "%0.1f%%")
plt.title("Average Ride Length Member vs Casual Riders in 2023")
plt.savefig('Average Ride Length Member vs Casual in 2023', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# visualization for average duration
# 平均持續時間的可視化

# %%
fig = plt.figure(figsize =(10, 7))
sns.barplot(x='weekday', y='ride_length', hue = 'member_casual', data=data_cleaned_2)
plt.title("Average Ride Length Member vs Casual on Day of Week")
plt.xlabel("Day of Week")
plt.ylabel("Average Ride Length")
plt.savefig('Average Ride Length Member vs Casual on Day of Week.png', dpi=300)
plt.show()
# Out:
# c:\Users\Admin\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\Admin\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# Average Ride Length Member vs Casual on Month of Year
# 一年中月份會員與休閒會員的平均騎乘時長

# %%
fig = plt.figure(figsize =(10, 7))
sns.barplot(x='month_name', y='ride_length', hue = 'member_casual', data=data_cleaned_3)
plt.title("Average Ride Length Member vs Casual on Month of Year")
plt.xlabel("Month of Year")
plt.ylabel("Average Ride Length")
plt.savefig('Average Ride Length Member vs Casual on Month of Year.png', dpi=300)
plt.show()

# %% [markdown]
# Rideable types compare to riders
# 可騎乘類型與騎士的比較

# %%
fig = plt.figure(figsize =(10, 7))
sns.barplot(x='rideable_type', y='count', hue = 'member_casual', data=data_cleaned_4)
plt.title("Rideable types compare to riders")
plt.xlabel("Rideable Type")
plt.ylabel("Number of riders")
plt.savefig('Rideable types compare to riders.png', dpi=300)
plt.show()

# %%
fig = plt.figure(figsize =(12, 10))
sns.relplot(kind = 'line',x='month', y='ride_id', hue = 'member_casual', data=data_cleaned_5)
plt.title("Monthly Ridership", y = 0.95)
plt.xlabel("Month")
plt.ylabel("Number of riders")
plt.savefig('Monthly Ridership.png', dpi=250)
plt.show()
# Out:
# c:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Data analysis chinese數據分析中文

# %%
data_cleaned = pd.read_csv("data_clean.csv")
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4244189 entries, 0 to 4244188
# Data columns (total 20 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   ride_id             object
#  2   rideable_type       object
#  3   started_at          object
#  4   ended_at            object
#  5   start_station_name  object
#  6   start_station_id    object
#  7   end_station_name    object
#  8   end_station_id      object
#  9   start_lat           float64
#  10  start_lng           float64
#  11  end_lat             float64
#  12  end_lng             float64
#  13  member_casual       object
#  14  ride_length         int64
#  15  weekday             object
#  16  day                 int64
#  17  month               int64
#  18  month_name          object
#  19  year                int64
# dtypes: float64(4), int64(5), object(11)
# memory usage: 647.6+ MB

# %% [markdown]
# Percentage of total users
# 佔總用戶的百分比

# %%
data_cleaned['member_casual_chinese'] = data_cleaned['member_casual'].map({'member': '會員', 'casual': '臨時使用者'})
percent1 = round(data_cleaned["member_casual_chinese"].value_counts(normalize = True) * 100, 1)
percent1
# Out:
# member_casual_chinese
# 會員       64.5
# 臨時使用者    35.5
# Name: proportion, dtype: float64

# %% [markdown]
# See the average ride length by each day for members vs casual user
# 查看會員與休閒用戶每天的平均騎乘長度

# %%
data_cleaned.groupby(['member_casual','weekday']).ride_length.mean()
# Out:
# member_casual  weekday
# casual         Friday       22.199486
#                Monday       22.434500
#                Saturday     25.879738
#                Sunday       26.547451
#                Thursday     19.842879
#                Tuesday      20.371842
#                Wednesday    19.441420
# member         Friday       11.810818
#                Monday       11.303922
#                Saturday     13.408318
#                Sunday       13.422293
#                Thursday     11.364379
#                Tuesday      11.398053
#                Wednesday    11.332991
# Name: ride_length, dtype: float64

# %% [markdown]
# fix the days of the week that are out of order
# 修復一週中不按順序排列的日子。

# %%
day_order = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']
data_cleaned['weekday'] = pd.Categorical(data_cleaned['weekday'], categories=day_order, ordered=True)
data_cleaned
# Out:
#          Unnamed: 0           ride_id  rideable_type           started_at  \
# 0                 0  F96D5A74A3E41399  electric_bike  2023-01-21 20:05:42
# 1                 1  13CB7EB698CEDB88   classic_bike  2023-01-10 15:37:36
# 2                 2  BD88A2E670661CE5  electric_bike  2023-01-02 07:51:57
# 3                 3  C90792D034FED968   classic_bike  2023-01-22 10:52:58
# 4                 4  3397017529188E8A   classic_bike  2023-01-12 13:58:01
# ...             ...               ...            ...                  ...
# 4244184     4244184  F74DF9549B504A6B  electric_bike  2023-12-07 13:15:24
# 4244185     4244185  BCDA66E761CC1029   classic_bike  2023-12-08 18:42:21
# 4244186     4244186  D2CF330F9C266683   classic_bike  2023-12-05 14:09:11
# 4244187     4244187  3829A0D1E00EE970  electric_bike  2023-12-02 21:36:07
# 4244188     4244188  A373F5B447AEA508   classic_bike  2023-12-11 13:07:46
#
#                     ended_at           start_station_name start_station_id  \
# 0        2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2        2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3        2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4        2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                      ...                          ...              ...
# 4244184  2023-12-07 13:17:37            900 W Harrison St            13028
# 4244185  2023-12-08 18:45:56            900 W Harrison St            13028
# 4244186  2023-12-05 14:13:01            900 W Harrison St            13028
# 4244187  2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 4244188  2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  ...  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074  ...
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568  ...
# 2        Valli Produce - Evanston Plaza            599  42.008571  ...
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568  ...
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568  ...
# ...                                 ...            ...        ...  ...
# 4244184      Racine Ave & Congress Pkwy   TA1306000025  41.874702  ...
# 4244185      Racine Ave & Congress Pkwy   TA1306000025  41.874754  ...
# 4244186      Racine Ave & Congress Pkwy   TA1306000025  41.874754  ...
# 4244187            Morgan St & Lake St*   chargingstx4  41.881396  ...
# 4244188      Racine Ave & Congress Pkwy   TA1306000025  41.874754  ...
#
#            end_lat    end_lng  member_casual ride_length   weekday day  month  \
# 0        41.930000 -87.640000         member          10  Saturday  21      1
# 1        41.809835 -87.599383         member           8   Tuesday  10      1
# 2        42.039742 -87.699413         casual          13    Monday   2      1
# 3        41.809835 -87.599383         member           8    Sunday  22      1
# 4        41.809835 -87.599383         member          15  Thursday  12      1
# ...            ...        ...            ...         ...       ...  ..    ...
# 4244184  41.874640 -87.657030         casual           2  Thursday   7     12
# 4244185  41.874640 -87.657030         casual           3    Friday   8     12
# 4244186  41.874640 -87.657030         member           3   Tuesday   5     12
# 4244187  41.885492 -87.652289         casual          17  Saturday   2     12
# 4244188  41.874640 -87.657030         member           3    Monday  11     12
#
#          month_name  year  member_casual_chinese
# 0           January  2023                     會員
# 1           January  2023                     會員
# 2           January  2023                  臨時使用者
# 3           January  2023                     會員
# 4           January  2023                     會員
# ...             ...   ...                    ...
# 4244184    December  2023                  臨時使用者
# 4244185    December  2023                  臨時使用者
# 4244186    December  2023                     會員
# 4244187    December  2023                  臨時使用者
# 4244188    December  2023                     會員
#
# [4244189 rows x 21 columns]

# %% [markdown]
# The average ride time by each day for members vs casual user
# 會員與休閒用戶每天的平均騎乘時間

# %%
data_cleaned.groupby(['member_casual','weekday']).ride_length.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11208\2585966250.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data_cleaned.groupby(['member_casual','weekday']).ride_length.mean()
# member_casual  weekday
# casual         Sunday       26.547451
#                Monday       22.434500
#                Tuesday      20.371842
#                Wednesday    19.441420
#                Thursday     19.842879
#                Friday       22.199486
#                Saturday     25.879738
# member         Sunday       13.422293
#                Monday       11.303922
#                Tuesday      11.398053
#                Wednesday    11.332991
#                Thursday     11.364379
#                Friday       11.810818
#                Saturday     13.408318
# Name: ride_length, dtype: float64

# %% [markdown]
# Above group by columns member_casual and weekday becomes Index of the DataFrame, In order to get these as a SQL like group by use as_index =False param or use reset_index().
#
# See the average ride time by each month for members vs casual user
#
# 上面的 group by 欄位 member_casual 和 weekday 成為 DataFrame 的索引，為了透過使用 as_index =False 參數或使用 reset_index() 將它們作為類似 SQL 的群組。
#
# 查看會員與休閒用戶每月的平均乘車時間

# %% [markdown]
# # Data visualization 數據視覺化

# %% [markdown]
# Visualize Percentage of Total Users
# 總用戶的百分比可視化

# %%
# Get data as lists (optional but useful for customization)
members = percent1['會員'].tolist()
casual_users = percent1['臨時使用者'].tolist()

# Set labels
labels = ['會員', '臨時使用者']

# Create the pie chart
plt.pie(percent1, labels=labels, autopct="%1.1f%%")
plt.title("佔總用戶的百分比")  # Set title in Chinese

# Optional: Customize the plot further
plt.axis('equal')  # Equal aspect ratio ensures a circular pie chart
plt.savefig('佔總用戶的百分比.png', dpi=300, bbox_inches='tight')
# Show the chart
plt.show()

# %% [markdown]
# Average Ride Length Member vs Casual in 2023
# 2023 年會員與休閒的平均騎乘長度

# %%
mpl.rcParams['font.family'] = 'SimHei'  # Set font to SimHei for Chinese characters
mpl.rcParams['font.size'] = 14

# Assuming data_cleaned is a pandas DataFrame
data_cleaned_1 = data_cleaned.groupby('member_casual', as_index=False)['ride_length'].agg('mean')

# Add a column with Chinese member type labels (assuming 'member' and 'casual')
data_cleaned_1['member_casual_chinese'] = data_cleaned_1['member_casual'].map({'member': '會員', 'casual': '臨時使用者'})

# Create the pie chart
fig, ax = plt.subplots(figsize=(8, 8))  # Adjust figure size if needed
plt.pie(data_cleaned_1['ride_length'], labels=data_cleaned_1['member_casual_chinese'], autopct="%0.1f%%", startangle=140)  # Set start angle for better readability

# Set title and legend text in Chinese
plt.title("2023年會員與臨時使用者的平均騎行時長", fontsize=16)  # Title: Average Ride Length...
plt.legend(data_cleaned_1['member_casual_chinese'], loc="upper left", title="會員類別", bbox_to_anchor=(1, 1))  # Legend

# Save the plot (optional)
plt.savefig('2023年會員與臨時使用者的平均騎行時長.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# visualization for average duration
# 平均持續時間的可視化

# %%
# Assuming data_cleaned_2 is as shown in the image (structure, not exact values)
# Define Traditional Chinese labels
member_casual_chinese = {'casual': '臨時使用者', 'member': '會員'}
weekday_chinese = {'Sunday': '星期日', 'Monday': '星期一', 'Tuesday': '星期二',
                   'Wednesday': '星期三', 'Thursday': '星期四', 'Friday': '星期五',
                   'Saturday': '星期六'}

data_cleaned_2['member_casual_chinese'] = data_cleaned_2['member_casual'].map(member_casual_chinese)
data_cleaned_2['weekday_chinese'] = data_cleaned_2['weekday'].map(weekday_chinese)

# Create the chart (assuming you want a bar chart)
fig, ax = plt.subplots(figsize=(10, 7))  # Adjust figure size as needed
sns.barplot(x='weekday_chinese', y='ride_length', hue='member_casual_chinese', data=data_cleaned_2)

# Set title, labels, and legend text in Traditional Chinese
plt.title("騎行日與會員類型的平均騎行時長", fontsize=14)  # Title: Average Ride Length...
plt.xlabel("騎行日", fontsize=12)  # X-axis label
plt.ylabel("平均騎行時長", fontsize=12)  # Y-axis label
plt.legend(title="會員類型", loc="upper left", bbox_to_anchor=(1, 1))  # Legend
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.tight_layout()  # Adjust spacing for better readability
plt.savefig('騎行日與會員類型的平均騎行時長.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# c:\Users\Admin\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\Admin\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# Average Ride Length Member vs Casual on Month of Year
# 一年中月份會員與休閒會員的平均騎乘時長

# %%
# Assuming data_cleaned is a pandas DataFrame
data_cleaned_3 = data_cleaned.groupby(['member_casual', 'month', 'month_name'], as_index=False)['ride_length'].agg('mean')

# Define Traditional Chinese month names (assuming you have month data as 1-12)
month_name_chinese = {1: '一月', 2: '二月', 3: '三月', 4: '四月', 5: '五月', 6: '六月',
                       7: '七月', 8: '八月', 9: '九月', 10: '十月', 11: '十一月', 12: '十二月'}
member_casual_chinese = {'casual': '臨時使用者', 'member': '會員'}
# Add a column with Traditional Chinese month names based on month number
data_cleaned_3['month_name_chinese'] = data_cleaned_3['month'].map(month_name_chinese)
data_cleaned_3['member_casual_chinese'] = data_cleaned_3['member_casual'].map(member_casual_chinese)
# Assuming you want a pivot table for this data
data_pivoted = pd.pivot_table(data_cleaned_3, index='member_casual_chinese', columns='month_name_chinese', values='ride_length')

fig = plt.figure(figsize =(10, 7))
sns.barplot(x='month_name_chinese', y='ride_length', hue = 'member_casual_chinese', data=data_cleaned_3)
plt.title("會員類別與月份的平均騎行時長", fontsize=14)  # Title: Average Ride Length...
plt.xlabel("月份", fontsize=12)  # X-axis label
plt.ylabel("會員類別", fontsize=12)  # Y-axis label
plt.savefig('會員類別與月份的平均騎行時長.png', dpi=300)
plt.show()

# %% [markdown]
# Rideable types compare to riders
# 可騎乘類型與騎士的比較

# %%
# Assuming data_cleaned is a pandas DataFrame
data_cleaned_4 = data_cleaned.groupby(['member_casual', 'rideable_type'])['ride_id'].count().rename_axis(['member_casual', 'rideable_type']).reset_index(name='count')

# Define Traditional Chinese labels for member_casual and rideable_type
member_casual_chinese = {'casual': '臨時使用者', 'member': '會員'}
rideable_type_chinese = {'classic_bike': '普通自行車', 'electric_bike': '電動輔助自行車', 'docked_bike': '共享單車'}

# Add columns with Traditional Chinese labels
data_cleaned_4['member_casual_chinese'] = data_cleaned_4['member_casual'].map(member_casual_chinese)
data_cleaned_4['rideable_type_chinese'] = data_cleaned_4['rideable_type'].map(rideable_type_chinese)

# Assuming you want a bar chart to compare ride counts
plt.figure(figsize=(8, 6))
sns.barplot(x='rideable_type_chinese', y='count', hue='member_casual_chinese', data=data_cleaned_4)

# Set chart title, labels, and legend text in Traditional Chinese
plt.title("會員類別與騎乘類型的騎乘次數", fontsize=14)  # Title: Ride Count...
plt.xlabel("會員類別", fontsize=12)  # X-axis label
plt.ylabel("騎乘次數", fontsize=12)  # Y-axis label
plt.legend(title="騎乘類型", loc='upper left', bbox_to_anchor=(1, 1))  # Legend
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.tight_layout()  # Adjust spacing for better readability
plt.savefig('會員類別與騎乘類型的騎乘次數.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming you're using pandas for data_cleaned_5

mpl.rcParams['font.family'] = 'SimHei'  # Set font to SimHei for Traditional Chinese characters
mpl.rcParams['font.size'] = 14

# Assuming data_cleaned is a pandas DataFrame
data_cleaned_5 = data_cleaned.groupby(['member_casual', 'month', 'month_name'], as_index=False)['ride_id'].agg('count')

# Define Traditional Chinese month names (assuming you have month data as 1-12)
month_name_chinese = {1: '一月', 2: '二月', 3: '三月', 4: '四月', 5: '五月', 6: '六月',
                       7: '七月', 8: '八月', 9: '九月', 10: '十月', 11: '十一月', 12: '十二月'}
member_casual_chinese = {'casual': '臨時使用者', 'member': '會員'}
# Add a column with Traditional Chinese month names based on month number
data_cleaned_5['month_name_chinese'] = data_cleaned_5['month'].map(month_name_chinese)
data_cleaned_5['member_casual_chinese'] = data_cleaned_5['member_casual'].map(member_casual_chinese)
# Assuming you want a line chart to show trends across months
plt.figure(figsize=(10, 6))
for member_type in data_cleaned_5['member_casual_chinese'].unique():
  data_filtered = data_cleaned_5.loc[data_cleaned_5['member_casual_chinese'] == member_type]
  plt.plot(data_filtered['month_name_chinese'], data_filtered['ride_id'], label=member_type)

# Set chart title, labels, and legend text in Traditional Chinese
plt.title("每月各會員類別的騎乘次數", fontsize=14)  # Title: Ride Count..
plt.xlabel("月份", fontsize=12)  # X-axis labe
plt.ylabel("騎乘次數", fontsize=12)  # Y-axis label
plt.legend(title="會員類別", loc='upper left', bbox_to_anchor=(1, 1))  # Legend
plt.xticks(rotation=15)  # Rotate x-axis labels for readability
plt.tight_layout()  # Adjust spacing for better readability
plt.savefig('每月各會員類別的騎乘次數.png', dpi=300)
plt.show()
